# %%
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use(["seaborn-v0_8", "paper.mplstyle"])
# plt.rcParams["lines.linewidth"] = 2

# %% [markdown]
# La ecuación diferencial es
# $$
# dy/dx = y(1-y)
# $$
# o
# $$
# 1\cdot dy/dx = y(1-y)
# $$
#
# de donde se obtiene
# $$
# u = 1 \\
# v = y(1-y)
# $$

# %%
# y' = y(1-y)
x = np.linspace(-1.5,1.5,11)
y = x.copy()
x,y = np.meshgrid(x,y)
u = x*0 + 1
v = y*(1-y)
plt.figure(figsize=(4,4))
plt.streamplot(x,y,u,v)
plt.axis("equal")
plt.quiver(x,y,u,v, color="red")
plt.axis("equal")
# Out:
# (-1.5, 1.5, -1.5, 1.5)

# %% [markdown]
# Si se considera la ecuación de circulos concentricos
# $$
# x^2 + y^2 = c^2
# $$
#
# y se deriva respecto a $x$, entonces se obtiene
# $$
# 2x + 2y\frac{dy}{dx} = 0
# $$
#
# despejando se obtiene la ecuación diferencial
# $$
# \frac{dy}{dx} = -\frac{x}{y}
# $$
#
# para evitar diviciones por cero, es mejor despejar para no tener divisiones en $u$ o en $v$
# $$
# y\frac{dy}{dx} = -x
# $$
#
# de donde se obtiene
# $$
# u = y \\
# v = -x
# $$

# %% [markdown]
# Otra forma de verlo es que la pendiente $dy/dx$ es el vector que define la dirección de las curvas, en dirección $v/u$

# %%
x = np.linspace(-5,5,11)
y = x.copy()
x,y = np.meshgrid(x,y)
u = y
v = -x
plt.figure(figsize=(4,4))
plt.streamplot(x,y,u,v)
plt.axis("equal")
plt.quiver(x,y,u,v, color="red")
plt.axis("equal")
# Out:
# (-5.0, 5.0, -5.0, 5.0)

# %%
# y' = 1 + y^2
x = np.linspace(-5,5,101)
y = x.copy()
x,y = np.meshgrid(x,y)
u = x*0 + 1
v = 1 + y**2
plt.figure(figsize=(4,4))
plt.streamplot(x,y,u,v)
plt.axis("equal")
plt.quiver(x,y,u,v, color="red")
# plt.contour(x,y,v/u, colors="k")
plt.axis("equal")
# Out:
# (-5.0, 5.0, -5.0, 5.0)
